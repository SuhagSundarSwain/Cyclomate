# %%
import cv2
import glob
import numpy as np
import matplotlib.pyplot as plt

# %%
image = cv2.imread('cyclone_image.jpg')

# %%
cyclone_image = image[500:,200:,:]

# %%
kernel1 = np.ones( (3,3), dtype=np.uint8 )
erode_img1 = cv2.erode(cyclone_image,kernel1,iterations=2)
dil_img1 = cv2.dilate(erode_img1,kernel1,iterations=1)

# %%
gray_test_image = cv2.cvtColor(dil_img1, cv2.COLOR_BGR2GRAY)

# %%
scaled_gray_image = cv2.convertScaleAbs(gray_test_image, alpha=1.12, beta=-20)

# %%
def Hist(image):
    H = np.zeros(shape=256)
    s = image.shape
    for i in range(s[0]):
        for j in range(s[1]):
            k = image[i,j]
            H[k] += 1
    return H

# %%
hist_test_image = Hist(scaled_gray_image)

# %%
plt.plot(hist_test_image)
cv2.imwrite('Hist.png', hist_test_image)
# Out:
# True

# %% [markdown]
# # Matching

# %%
matching = 0
f = ''
for image in glob.glob('Histogram_scaled_gray_Dataset/*'):
    saved = cv2.imread(image)
    hist_saved = Hist(saved)
    
    relation = np.corrcoef(hist_test_image,hist_saved)
    if (relation[0,1]>matching):
        matching = relation[0,1]
        f = image[30:]
    print(relation[0,1])
print(matching)
print(f)
# Out:
# 0.8227481608910913
# 0.542356796926487
# 0.9038869737840712
# 0.891105414358403
# 0.8332199242820071
# -0.013487901981575522
# 0.2675885672109103
# 0.8368857476401709
# 0.8325858210084376
# 0.9351039860692933
# 0.9296997315032371
# 0.03490833101918601
# 0.731463821209423
# 0.003830204185529357
# 0.8891755370590682
# 0.9174881385182168
# 0.9190413985547565
# 0.90671391628693
# 0.1544670062738302
# 0.6946232889925354
# 0.9317941899291518
# 0.9378773460989406
# 0.9007170550980088
# 0.38975048769486165
# 0.7281054765356969
# 0.9205308708392219
# 0.9412966005361768
# 0.8429939933264083
# -0.0004223103024155558
# 0.19018338863377335
# 0.24702466002704573
# 0.5108334958368977
# 0.8820056903064869
# 0.9183732007130269
# 0.7598305543076037
# -0.014803983065005117
# 0.11874549789912087
# 0.4398662367122783
# 0.35981516496556554
# 0.7020142964988055
# 0.7272064253475082
# 0.7401848303586422
# -0.09477978770913864
# 0.045848415003161884
# 0.9059426091174863
# 0.5708014149395163
# 0.889780623358756
# 0.9355137965876565
# 0.922610054254335
# -0.034362194811436514
# 0.5307137400654903
# 0.5585709071876199
# 0.9204001337605924
# 0.9503509458177204
# 0.901731722310267
# 0.9309543500019412
# -0.04180810966141267
# 0.19948043300015295
# 0.6092315756189813
# 0.6943867523771187
# 0.9308773607496565
# 0.9402811363892346
# 0.1785990617665683
# 0.8907635032970623
# 0.9123153791369223
# 0.8728593318227488
# 0.9365163222634515
# 0.9587951175072646
# 0.23179234212562214
# 0.7236351695029851
# 0.8880340360122891
# 0.8639677325228848
# 0.9526609966084424
# 0.922087333119421
# 0.9384236524474228
# 0.1478044769507207
# 0.7702301719879124
# -0.03644860130086355
# 0.8497990206025493
# 0.8949046931638929
# 0.9119306126947807
# 0.9604107289234227
# 0.2444945626536885
# 0.7355137931025375
# -0.03644860130086355
# 0.7884270596834687
# 0.9177246517644528
# 0.8796061855477294
# 0.8505893763458822
# 0.2613316217146093
# 0.5290861021204096
# 0.9604107289234227
# 29-04-2019  150000.jpg

# %%
matching = 0
f = ''
for image in glob.glob('Histogram_scaled_gray_Dataset/*'):
    saved = cv2.imread(image)
    hist_saved = Hist(saved)
    
    relation = np.corrcoef(hist_test_image,hist_saved)
    if (relation[0,1]>matching):
        matching = relation[0,1]
        f = image[30:]
    print(relation[0,1])
print(matching)
print(f)
# Out:
# 0.8227481608910913
# 0.542356796926487
# 0.9038869737840712
# 0.891105414358403
# 0.8332199242820071
# -0.013487901981575522
# 0.2675885672109103
# 0.8368857476401709
# 0.8325858210084376
# 0.9351039860692933
# 0.9296997315032371
# 0.03490833101918601
# 0.731463821209423
# 0.003830204185529357
# 0.8891755370590682
# 0.9174881385182168
# 0.9190413985547565
# 0.90671391628693
# 0.1544670062738302
# 0.6946232889925354
# 0.9317941899291518
# 0.9378773460989406
# 0.9007170550980088
# 0.38975048769486165
# 0.7281054765356969
# 0.9205308708392219
# 0.9412966005361768
# 0.8429939933264083
# -0.0004223103024155558
# 0.19018338863377335
# 0.24702466002704573
# 0.5108334958368977
# 0.8820056903064869
# 0.9183732007130269
# 0.7598305543076037
# -0.014803983065005117
# 0.11874549789912087
# 0.4398662367122783
# 0.35981516496556554
# 0.7020142964988055
# 0.7272064253475082
# 0.7401848303586422
# -0.09477978770913864
# 0.045848415003161884
# 0.9059426091174863
# 0.5708014149395163
# 0.889780623358756
# 0.9355137965876565
# 0.922610054254335
# -0.034362194811436514
# 0.5307137400654903
# 0.5585709071876199
# 0.9204001337605924
# 0.9503509458177204
# 0.901731722310267
# 0.9309543500019412
# -0.04180810966141267
# 0.19948043300015295
# 0.6092315756189813
# 0.6943867523771187
# 0.9308773607496565
# 0.9402811363892346
# 0.1785990617665683
# 0.8907635032970623
# 0.9123153791369223
# 0.8728593318227488
# 0.9365163222634515
# 0.9587951175072646
# 0.23179234212562214
# 0.7236351695029851
# 0.8880340360122891
# 0.8639677325228848
# 0.9526609966084424
# 0.922087333119421
# 0.9384236524474228
# 0.1478044769507207
# 0.7702301719879124
# -0.03644860130086355
# 0.8497990206025493
# 0.8949046931638929
# 0.9119306126947807
# 0.9604107289234227
# 0.2444945626536885
# 0.7355137931025375
# -0.03644860130086355
# 0.7884270596834687
# 0.9177246517644528
# 0.8796061855477294
# 0.8505893763458822
# 0.2613316217146093
# 0.5290861021204096
# 0.9604107289234227
# 29-04-2019  150000.jpg

# %%
all_hist =[]
file_Name = []

# %%
for image in glob.glob('Histogram_scaled_gray_Dataset/*'):
    saved = cv2.imread(image)
    hist_saved = Hist(saved)
    all_hist.append(hist_saved)
    file_Name.append(image[30:])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9136/848296732.py in <module>
#       1 for image in glob.glob('Histogram_scaled_gray_Dataset/*'):
#       2     saved = cv2.imread(image)
# ----> 3     hist_saved = Hist(saved)
#       4     all_hist.append(hist_saved)
#       5     file_Name.append(image[30:])
#
# ~\AppData\Local\Temp/ipykernel_9136/4222180729.py in Hist(image)
#       5         for j in range(s[1]):
#       6             k = image[i,j]
# ----> 7             H[k] += 1
#       8     return H
#
# KeyboardInterrupt:

# %%
all_hist

# %% [markdown]
# # Matching

# %%
matching = 0
for i in range(len(u)):
    hist_list = u[i]
    relation = np.corrcoef(hist_test_image,hist_list)
    if (relation[0,1]>matching):
        matching = relation[0,1]
        file = v[i]
print(matching)
print(file)
# Out:
# 0.9217858385811967
# ['18-05-2020  030000.jpg']

# %%
import pandas as pd

# %%
data_all_hist = pd.DataFrame(all_hist)

# %%
data_all_hist

# %%
data_file_name = pd.DataFrame(file_Name)

# %%
data_all_hist.to_csv('Histogram_datas.csv')

# %%
data_file_name.to_csv('Histogrm_file_names.csv')

# %% [markdown]
# # Time Taking

# %%
# Out:
# 0.635974907795592
# 0.7706349278200081
# 0.5033351650493567
# 0.5403502793697174
# 0.5531807370151579
# 0.6300844758626195
# 0.60630225685573
# 0.5546284021488592
# 0.5868294330537628
# 0.46049940362237507
# 0.5262005866294824
# 0.5007081019985042
# 0.5781888632689336
# 0.47543188669553327
# 0.5116371108677205
# 0.40585971713421765
# 0.37010293737770944
# 0.41761752115337475
# 0.42265240466469134
# 0.31070115255252456
# 0.5485047314863206
# 0.5437940848411086
# 0.4212838173796911
# 0.8325134546623829
# 0.7067377580753181

# %%
u = pd.read_csv('Histogram_datas.csv')

# %%
u = np.array(u)

# %%
u
# Out:
# array([[1347, 1816, 1994, ...,    0,    0,    0],
#        [1066, 1375, 1372, ...,    0,    0,    0],
#        [2582, 3139, 3312, ...,   35,   31,   64],
#        ...,
#        [1535, 2035, 2256, ...,   15,   21,   42],
#        [ 446,  586,  540, ...,    0,    0,    0],
#        [ 980, 1433, 1496, ...,    0,    0,    0]], dtype=int64)

# %%
v = pd.read_csv('Histogrm_file_names.csv')

# %%
v = np.array(v)

# %%
v
# Out:
# array([['01-05-2019  030000.jpg'],
#        ['01-05-2019  060000.jpg'],
#        ['01-05-2019  090000.jpg'],
#        ['01-05-2019  120000.jpg'],
#        ['01-05-2019  150000.jpg'],
#        ['01-05-2019  180000.jpg'],
#        ['01-05-2019  210000.jpg'],
#        ['02-05-2019  030000.jpg'],
#        ['02-05-2019  060000.jpg'],
#        ['02-05-2019  090000.jpg'],
#        ['02-05-2019  150000.jpg'],
#        ['02-05-2019  180000.jpg'],
#        ['02-05-2019  210000.jpg'],
#        ['03-05-2019  030000.jpg'],
#        ['03-05-2019  060000.jpg'],
#        ['03-05-2019  090000.jpg'],
#        ['03-05-2019  120000.jpg'],
#        ['03-05-2019  150000.jpg'],
#        ['03-05-2019  180000.jpg'],
#        ['03-05-2019  210000.jpg'],
#        ['04-05-2019  030000.jpg'],
#        ['04-05-2019  060000.jpg'],
#        ['04-05-2019  120000.jpg'],
#        ['16-05-2020  030000.jpg'],
#        ['16-05-2020  060000.jpg'],
#        ['16-05-2020  090000.jpg'],
#        ['16-05-2020  120000.jpg'],
#        ['16-05-2020  150000.jpg'],
#        ['16-05-2020  180000.jpg'],
#        ['16-05-2020  210000.jpg'],
#        ['17-05-2020  030000.jpg'],
#        ['17-05-2020  060000.jpg'],
#        ['17-05-2020  090000.jpg'],
#        ['17-05-2020  120000.jpg'],
#        ['17-05-2020  150000.jpg'],
#        ['17-05-2020  180000.jpg'],
#        ['17-05-2020  210000.jpg'],
#        ['18-05-2020  030000.jpg'],
#        ['18-05-2020  060000.jpg'],
#        ['18-05-2020  090000.jpg'],
#        ['18-05-2020  120000.jpg'],
#        ['18-05-2020  150000.jpg'],
#        ['18-05-2020  180000.jpg'],
#        ['18-05-2020  210000.jpg'],
#        ['19-05-2020  030000.jpg'],
#        ['19-05-2020  060000.jpg'],
#        ['19-05-2020  090000.jpg'],
#        ['19-05-2020  120000.jpg'],
#        ['19-05-2020  150000.jpg'],
#        ['19-05-2020  180000.jpg'],
#        ['19-05-2020  210000.jpg'],
#        ['20-05-2020  030000.jpg'],
#        ['20-05-2020  060000.jpg'],
#        ['20-05-2020  090000.jpg'],
#        ['20-05-2020  120000.jpg'],
#        ['20-05-2020  150000.jpg'],
#        ['20-05-2020  180000.jpg'],
#        ['20-05-2020  210000.jpg'],
#        ['21-05-2020  030000.jpg'],
#        ['21-05-2020  060000.jpg'],
#        ['21-05-2020  120000.jpg'],
#        ['26-04-2019  120000.jpg'],
#        ['26-04-2019  180000.jpg'],
#        ['27-04-2019  030000.jpg'],
#        ['27-04-2019  060000.jpg'],
#        ['27-04-2019  090000.jpg'],
#        ['27-04-2019  120000.jpg'],
#        ['27-04-2019  150000.jpg'],
#        ['27-04-2019  180000.jpg'],
#        ['27-04-2019  210000.jpg'],
#        ['28-04-2019  030000.jpg'],
#        ['28-04-2019  060000.jpg'],
#        ['28-04-2019  090000.jpg'],
#        ['28-04-2019  120000.jpg'],
#        ['28-04-2019  150000.jpg'],
#        ['28-04-2019  180000.jpg'],
#        ['28-04-2019  210000.jpg'],
#        ['29-04-2019  030000.jpg'],
#        ['29-04-2019  060000.jpg'],
#        ['29-04-2019  090000.jpg'],
#        ['29-04-2019  120000.jpg'],
#        ['29-04-2019  150000.jpg'],
#        ['29-04-2019  180000.jpg'],
#        ['29-04-2019  210000.jpg'],
#        ['30-04-2019  030000.jpg'],
#        ['30-04-2019  060000.jpg'],
#        ['30-04-2019  090000.jpg'],
#        ['30-04-2019  120000.jpg'],
#        ['30-04-2019  150000.jpg'],
#        ['30-04-2019  180000.jpg'],
#        ['30-04-2019  210000.jpg']], dtype=object)
